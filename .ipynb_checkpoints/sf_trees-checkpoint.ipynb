# %%
# importing modules

import pandas as pd
import altair as alt
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import fidap
import config
from shapely import wkt
import statsmodels.api as sm
import libpysal as lps
import spreg
import esda
from libpysal.weights import Queen, KNN

# instantiating connection 
fidap = fidap.fidap_client(api_key=config.api_key)

# %% [markdown]
# ### Urban Trees Cover: San Francisco
#
# The original idea was to look at tree cover in New York City and San Francisco. But the SF dataset is more updated than the one in New York City. So why not just look at SF?
#
# Some of the questions we can answer include:
# 1) What are the spatial and socio-economic distributions of trees within an urban setting?
# 2) Are historically under-privileged neighborhoods marginalized even in terms of greenery cover?
# 3) Which are some of the oldest trees in these cities?
# 4) Can we correlate urban heat island effect with tree cover using existing data?

# %%
# taking a look at sf trees
sf_trees = fidap.sql("""
SELECT tree_id, species, site_info, care_taker, CAST(plant_date AS STRING) AS plant_date, latitude, longitude, ST_GEOGPOINT(longitude, latitude) AS location
FROM bigquery-public-data.san_francisco_trees.street_trees
WHERE latitude IS NOT NULL
AND longitude IS NOT NULL;
""")

# sf neighborhoods
sf_neighborhoods = fidap.sql("""
SELECT neighborhood, neighborhood_geom, ST_AREA(neighborhood_geom)/2589988.1  AS area_sqmi
FROM bigquery-public-data.san_francisco_neighborhoods.boundaries
""")

# %%
print("Tree Density of SF: " + str(round(sf_trees.shape[0]/46.87, 2)) + " per sq. mile")
# Out:
# Tree Density of SF: 4104.25 per sq. mile

# %% [markdown]
# **Common Trees**

# %%
# 10 most common trees
common_trees = sf_trees.loc[(sf_trees['species'] != 'Tree(s) ::')]
common_trees = common_trees.groupby('species').agg('count').reset_index()
common_trees = common_trees[['species', 'tree_id']]
common_trees = common_trees.rename(columns = {'tree_id': 'n_trees'})
common_trees = common_trees.sort_values('n_trees', ascending=False)
common_trees.head(n = 10)
# Out:
#                                                species  n_trees
# 402     Platanus x hispanica :: Sycamore: London Plane    11593
# 341      Metrosideros excelsa :: New Zealand Xmas Tree     8730
# 301              Lophostemon confertus :: Brisbane Box     8657
# 545              Tristaniopsis laurina :: Swamp Myrtle     7349
# 395             Pittosporum undulatum :: Victorian Box     7127
# 424                   Prunus cerasifera :: Cherry Plum     6697
# 314          Magnolia grandiflora :: Southern Magnolia     6318
# 64          Arbutus 'Marina' :: Hybrid Strawberry Tree     5635
# 210  Ficus microcarpa nitida 'Green Gem' :: Indian ...     5580
# 440  Prunus serrulata 'Kwanzan' :: Kwanzan Flowerin...     4007

# %% [markdown]
# **Oldest Trees in SF**

# %%
# 10 oldest trees 

## get trees with known dates of planting
## convert the plant date column
oldest_trees = sf_trees[sf_trees.plant_date.notnull()].copy()
oldest_trees['plant_date_dt'] = pd.to_datetime(oldest_trees['plant_date'])
oldest_trees = oldest_trees.sort_values('plant_date_dt')

## display head
oldest_trees.head(n=10)
# Out:
#         tree_id  ...             plant_date_dt
# 52437     53719  ... 1955-09-19 00:00:00+00:00
# 128111    30314  ... 1955-10-20 00:00:00+00:00
# 52637     30312  ... 1955-10-20 00:00:00+00:00
# 52638     30313  ... 1955-10-20 00:00:00+00:00
# 123875    30316  ... 1955-10-24 00:00:00+00:00
# 123876    30315  ... 1955-10-24 00:00:00+00:00
# 54022     48435  ... 1955-10-24 00:00:00+00:00
# 144539    30318  ... 1955-12-13 00:00:00+00:00
# 134480    30320  ... 1955-12-13 00:00:00+00:00
# 144538    30319  ... 1955-12-13 00:00:00+00:00
#
# [10 rows x 9 columns]

# %% [markdown]
# **Leafiest Neighborhoods and Census Tracts in SF**
# Where are the neighborhoods with the highest tree coverage?

# %%
# converting both queries into gdf
sf_neighborhoods['neighborhood_geom'] = sf_neighborhoods['neighborhood_geom'].apply(wkt.loads) 
sf_neighborhoods_gdf = gpd.GeoDataFrame(sf_neighborhoods, geometry = 'neighborhood_geom', crs = 'epsg:4326')

sf_trees['location'] = sf_trees['location'].apply(wkt.loads)
sf_trees_gdf = gpd.GeoDataFrame(sf_trees, geometry = 'location', crs = 'epsg:4326')

# spatial join of trees to neighborhoods
sf_trees_neighborhood = gpd.sjoin(sf_trees_gdf, sf_neighborhoods_gdf, how = 'inner', op = 'intersects')

# count of trees
sf_trees_neighborhood_count = sf_trees_neighborhood.groupby('neighborhood').agg('count').reset_index()
sf_trees_neighborhood_count = sf_trees_neighborhood_count[['neighborhood', 'tree_id']].rename(columns = {'tree_id': 'n_trees'})

# get density of trees per neighborhood
sf_trees_neighborhood_count = sf_neighborhoods_gdf.merge(sf_trees_neighborhood_count)
sf_trees_neighborhood_count['density'] = sf_trees_neighborhood_count['n_trees']/sf_trees_neighborhood_count['area_sqmi']

# %% [markdown]
# Alternatively, if you do not feel like using `Python` to arrive at the answer, we can do so with `SQL` as well.

# %%
# SQL alternative to arriving at the density figure
sf_trees_neighborhood_count = fidap.sql("""
WITH trees AS(
SELECT tree_id, ST_GEOGPOINT(longitude, latitude) AS tree_geom
FROM bigquery-public-data.san_francisco_trees.street_trees
WHERE latitude IS NOT NULL
AND longitude IS NOT NULL
), 

sf_neighborhood AS(
SELECT neighborhood, neighborhood_geom, ST_AREA(neighborhood_geom)/2589988.1  AS area_sqmi
FROM bigquery-public-data.san_francisco_neighborhoods.boundaries
)

SELECT COUNT(*) AS n_trees, s.neighborhood, s.area_sqmi , ROUND(COUNT(*)/s.area_sqmi,2) AS tree_density 
FROM trees AS t, sf_neighborhood AS s
WHERE ST_CONTAINS(s.neighborhood_geom, t.tree_geom)
GROUP BY s.neighborhood, s.area_sqmi;
""")

# %%
# visualizing it 
fig, ax = plt.subplots(figsize = (12,9))
sf_trees_neighborhood_count.plot(ax = ax, column = 'density', cmap = 'RdYlGn', legend = True, legend_kwds = {'orientation':'horizontal'})
fig.suptitle("Density of Trees in each SF Neighborhood")
ax.set_axis_off()
plt.show()

# %% [markdown]
# What if you do not want to see it at the scale of SF neighborhoods? Perhaps Census Tracts are a much better fit for this job as it can contain socio-economic information gathered by the Census Bureau.

# %%
# obtaining boundaries data from SF Open Data Portal
census_tracts_sf_neighborhood = fidap.sql("""
SELECT ST_GEOGFROMTEXT(the_geom) AS geometry, NHOOD, CONCAT('0', CAST(GEOID AS STRING)) AS geoid, ST_AREA(ST_GEOGFROMTEXT(the_geom))/2589988.1 AS tract_area
FROM fidap-301014.sf_census_tracts.census_tracts
""")

# reading it in as a CSV gives rise to problems as the leading zero is omitted 
census_tracts_sf_neighborhood['GEOID'] = census_tracts_sf_neighborhood.GEOID.astype(str)
census_tracts_sf_neighborhood['GEOID'] = str('0') + census_tracts_sf_neighborhood['GEOID']

# querying for ACS data
census_data = fidap.sql("""
SELECT geo_id, 
total_pop, (black_pop + asian_pop + hispanic_pop + amerindian_pop + other_race_pop) AS non_white_pop, white_pop, 
median_age, income_per_capita
FROM bigquery-public-data.census_bureau_acs.censustract_2018_5yr
WHERE geo_id LIKE '06075%' 
""")

census_data = census_data.assign(
    non_white_pct = lambda x: round(100*x.non_white_pop/x.total_pop,2),
    white_pct = lambda x: round(100*x.white_pop/x.total_pop, 2),
    geo_id = lambda x: str('0') + x.geo_id.astype(str)
)

# merging it with boundaries file from SF Open Data 
census_tracts_data_sf = census_tracts_sf_neighborhood.merge(census_data, how = 'inner', left_on = 'GEOID', right_on = 'geo_id')

# converting it to gdf
census_tracts_data_sf['the_geom'] = census_tracts_data_sf['the_geom'].apply(wkt.loads)
census_tracts_data_sf_gdf = gpd.GeoDataFrame(census_tracts_data_sf, geometry = 'the_geom', crs = 'epsg:4326')
sf_trees_CT_df = gpd.sjoin(sf_trees_gdf, census_tracts_data_sf_gdf, how = 'inner', op = 'intersects')

# aggregating by census tract
sf_trees_CT_count = sf_trees_CT_df.groupby('GEOID').agg('count')
sf_trees_CT_count = sf_trees_CT_count.reset_index()
sf_trees_CT_count = sf_trees_CT_count[['GEOID', 'tree_id']].rename(columns = {'tree_id':'n_trees'})

# getting the geom back 
sf_trees_CT_gdf = census_tracts_data_sf_gdf.merge(sf_trees_CT_count, 'inner', 'GEOID')

# calculating tree density
sf_trees_CT_gdf = sf_trees_CT_gdf[['the_geom', 'GEOID', 'total_pop', 'non_white_pop', 'white_pop', 'median_age', 'income_per_capita', 'non_white_pct', 'white_pct', 'n_trees']]
sf_trees_CT_gdf = sf_trees_CT_gdf.to_crs('epsg:3857')
sf_trees_CT_gdf = sf_trees_CT_gdf.assign(
    area = lambda x: x.geometry.area/2589988.1103,
    tree_density = lambda x: x.n_trees/(x.geometry.area/2589988.1103)
)

# %% [markdown]
# Again, you can also stitch all of this together using SQL.

# %%
sf_trees_CT_sql = fidap.sql("""
WITH sf_CT AS (
SELECT ST_GEOGFROMTEXT(the_geom) AS geometry, NHOOD, CONCAT('0', CAST(GEOID AS STRING)) AS geoid, ST_AREA(ST_GEOGFROMTEXT(the_geom))/2589988.1 AS tract_area
FROM fidap-301014.sf_census_tracts.census_tracts),

trees AS(
SELECT tree_id, ST_GEOGPOINT(longitude, latitude) AS tree_geom, care_taker
FROM bigquery-public-data.san_francisco_trees.street_trees
WHERE latitude IS NOT NULL
AND longitude IS NOT NULL),

private_trees AS (
SELECT s.geoid, COUNT(*) AS n_private_trees
FROM trees AS t, sf_CT as s
WHERE ST_CONTAINS(s.geometry, t.tree_geom)
AND care_taker ='Private'
GROUP BY s.geoid, s.tract_area),

tree_density AS(
SELECT s.geoid, s.tract_area, COUNT(*) AS n_trees, ROUND(COUNT(*)/s.tract_area,2) AS tree_density 
FROM trees AS t, sf_CT AS s
WHERE ST_CONTAINS(s.geometry, t.tree_geom)
GROUP BY s.geoid, s.tract_area),

sf_ct_census AS(
SELECT geo_id, 
total_pop, (black_pop + asian_pop + hispanic_pop + amerindian_pop + other_race_pop) AS non_white_pop, white_pop,
(100*(black_pop + asian_pop + hispanic_pop + amerindian_pop + other_race_pop)/total_pop) AS non_white_pop_pct, (100*white_pop/total_pop) AS white_pop_pct,
median_age, income_per_capita/1000 AS income_per_capita_k
FROM bigquery-public-data.census_bureau_acs.censustract_2018_5yr
WHERE geo_id LIKE '06075%'
AND total_pop > 0),

sf_trees_ct AS (
SELECT t.geoid, t.tree_density, t.n_trees,
s.total_pop, ROUND(s.total_pop/t.tract_area,2) AS pop_density, s.non_white_pop_pct, s.white_pop_pct, 
s.median_age, s.income_per_capita_k
FROM sf_ct_census AS s  
INNER JOIN tree_density as t
ON t.geoid = s.geo_id),

sf_trees_ct2 AS(
SELECT sf.geoid, sf.tree_density, sf.n_trees, sf.total_pop, sf.pop_density, sf.non_white_pop_pct,sf.white_pop_pct, sf.median_age, sf.income_per_capita_k, ct.geometry
FROM sf_trees_ct AS sf
INNER JOIN sf_CT AS ct
ON sf.geoid = ct.geoid)

SELECT * , ROUND (100*pt.n_private_trees/n_trees,2) AS pct_private_trees
FROM sf_trees_ct2 AS sf2
INNER JOIN private_trees AS pt
ON sf2.geoid = pt.geoid;
""")

# converting to gdf
sf_trees_CT_sql['geometry'] = sf_trees_CT_sql.geometry.apply(wkt.loads)
sf_trees_CT_sql_gdf = gpd.GeoDataFrame(sf_trees_CT_sql, geometry = 'geometry', crs = 'epsg:4326')

# %%
# visualizing it 
fig, ax = plt.subplots(figsize = (12,9))
sf_trees_CT_gdf.plot(ax = ax, column = 'tree_density', 
                     cmap = 'RdYlGn', legend = True, 
                     legend_kwds = {'orientation':'vertical','label':'Trees per Sq.Mi.'})
fig.suptitle("Density of Trees in SF's Census Tracts")
ax.set_axis_off()
plt.show()

# %%
trees_income_scatter = alt.Chart(sf_trees_CT_sql_gdf).mark_circle().encode(
    x = 'income_per_capita_k',
    y = 'tree_density'
)
trees_income_scatter + trees_income_scatter.transform_regression(on = 'income_per_capita_k', regression = 'tree_density', method = 'linear').mark_line()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# **Factors Affecting Tree Density**
#
# What if we run a multiple OLS regression?

# %%
# split
x = sf_trees_CT_sql_gdf[['income_per_capita_k', 'white_pop_pct', 'pop_density']]
y = sf_trees_CT_sql_gdf[['tree_density']]

# running regression
lm = sm.OLS(y, x).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           tree_density   R-squared (uncentered):                   0.835
# Model:                            OLS   Adj. R-squared (uncentered):              0.832
# Method:                 Least Squares   F-statistic:                              323.0
# Date:                Wed, 28 Jul 2021   Prob (F-statistic):                    9.52e-75
# Time:                        23:00:14   Log-Likelihood:                         -1812.9
# No. Observations:                 195   AIC:                                      3632.
# Df Residuals:                     192   BIC:                                      3642.
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# income_per_capita_k    54.1548     12.608      4.295      0.000      29.288      79.022
# white_pop_pct           9.3196     19.288      0.483      0.630     -28.724      47.363
# pop_density             0.0530      0.007      7.482      0.000       0.039       0.067
# ==============================================================================
# Omnibus:                        7.320   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):                7.156
# Skew:                           0.401   Prob(JB):                       0.0279
# Kurtosis:                       3.488   Cond. No.                     4.58e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 4.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Okay. So we have established that income, race, and population density are significant factors to be taken into account when considering the density of trees in SF's census tracts.
#
# Consider the following proposition for a moment:
# We are assuming that values are normally distributed and each observation is independent of one another. That is, the density of trees in one census tract is independent of the densities of other tracts around it. But is it? Leafy neighborhoods are not typically surrounded by barren ones, and vice versa. Can we test this?
#
# Yes we can. We can do something called a Moran's test. We can take a look at each census tract, identify the tracts adjacent to it, and see if the tree density values of its surrounding tracts are correlated to itself.

# %%
# Creating spatial weights matrix and regimes
sf_trees_CT_gdf = sf_trees_CT_gdf.rename(columns = {'the_geom':'geometry'})
weights = Queen.from_dataframe(sf_trees_CT_gdf)
weights_untransformed = weights
weights.transform = "r"
# Out:
# ('WARNING: ', 183, ' is an island (no neighbors)')
# c:\users\wesch\appdata\local\programs\python\python37\lib\site-packages\libpysal\weights\weights.py:167: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#  There is 1 island with id: 183.
#   warnings.warn(message)

# %%
def moran_scatter_map(all_vars_df, dep_var, weights, titles, census_tracts):
    # Creating y_var
    y = all_vars_df[dep_var]
    # Creating a lag variable 
    lag_var = lps.weights.lag_spatial(weights, y)
    # lm for moran and plotting
    b, a  = np.polyfit(y, lag_var, 1)
    f, ax = plt.subplots(1, figsize=(9,9))

    plt.plot(y, lag_var, ".", color = "#fb8072")

    plt.vlines(y.mean(), lag_var.min(),lag_var.max(), linestyle = "--")
    plt.hlines(lag_var.mean(), y.min(), y.max(), linestyle = "--")

    # plot line of best fit using global I as slope
    plt.plot(y, a+b*y, "#8da0cb")
    plt.suptitle("Moran Scatterplot")
    plt.title("Global Moran's I Statistic:" + str(np.corrcoef(y, lag_var)[0,1]))
    plt.ylabel("Spatial Lag of " + titles)
    plt.xlabel(titles)
    plt.show()
    
    # calculating global Moran's 
    
    global_moran = esda.moran.Moran(y, weights)
    p_norm = global_moran.p_norm
    moran_statistic = round(global_moran.I, 3)
    
    print("Moran's p-value: " + str(p_norm))
    
    #calculating local moran's i 
    li = esda.moran.Moran_Local(y, weights)
    
    # classifying and quadrants (xy)
    sig = 1 * (li.p_sim < 0.05)
    highhigh = 1* (sig * li.q == 1)
    lowlow = 3* (sig * li.q == 3)
    lowhigh = 2* (sig * li.q == 2)
    highlow = 4* (sig * li.q == 4)

    spots = highhigh + lowlow + lowhigh + highlow
    spots_labels = ["0 Not Sig", "1 High-High", "2 Low-High", "3 Low-Low", "4 High-Low"]
    labels = [spots_labels[i] for i in spots]
    
    # plotting map
    from matplotlib import colors
    hmap = colors.ListedColormap(["#d9d9d9", "#fb8072", "#8dd3c7", "#80b1d3", "#bebada"])
    f, ax = plt.subplots(1, figsize=(9,9))
    relevant_tracts = all_vars_df.loc[:,["geometry"]]
    relevant_tracts = gpd.GeoDataFrame(relevant_tracts, crs = census_tracts.crs)
    relevant_tracts.assign(cl=labels).plot(column = "cl", categorical = True, k = 2, cmap = hmap, linewidth = 0.1, 
                                           ax = ax, edgecolor = "white", legend = True)
    ax.set_axis_off()
    ax.set_title("Spatial Association for " + titles)
    plt.show()

# %%
moran_scatter_map(sf_trees_CT_gdf, "tree_density", weights, "Tree Density / mi2", sf_trees_CT_gdf)
# Out:
# Moran's p-value: 0.0
# c:\users\wesch\appdata\local\programs\python\python37\lib\site-packages\esda\moran.py:886: RuntimeWarning: invalid value encountered in true_divide
#   self.z_sim = (self.Is - self.EI_sim) / self.seI_sim

# %% [markdown]
# So if we look at the scatter plot above, we see that there is a very strong positive correlation. In this plot,  each point's x-value is the density of trees per sqare mile for each census tract. The y-value is the density of trees per square mile for an adjacent census tract. In other words, if a census tract is surrounded by four others, there will be four points generated.
#
# The implication of this being, if the density of trees in a census tract is highly correlated to the ones surrounding it, then tracts with high values will be surrounded by similarly high-value tracts, and vice versa. Thus, giving rise to our strong positive correlation.
#
# We can also set it up as a hypothesis test, run a Monte Carlo simulation, and see how extreme this positive correlation is. Our p-value of 0.0 tells us that even at a 99% confidence interval, we reject the null hypothesis that there is no correlation in the distribution of values.
#
# What this means on the ground can then be seen in the map above. Tracts colored in red are clusters of high-value tracts surrounded by equally high-value tracts. The ones in blue are the exact opposite. Green are low-value tracts surrounded by high-value tracts, purple are high-value tracts surrounded by low-value ones. The ones in grey are not statistically significant enough to fall into any of the four categories outlined above.
